# %%
#Se importa la base de datos de países
# !pip install geopandas
import os, geopandas as gpd

countries=gpd.read_file(os.path.join("World_Countries"))
# Out:
# Requirement already satisfied: geopandas in c:\users\ruizd\anaconda3\lib\site-packages (1.0.1)
# Requirement already satisfied: numpy>=1.22 in c:\users\ruizd\anaconda3\lib\site-packages (from geopandas) (1.26.4)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\ruizd\anaconda3\lib\site-packages (from geopandas) (0.9.0)
# Requirement already satisfied: packaging in c:\users\ruizd\anaconda3\lib\site-packages (from geopandas) (23.2)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\ruizd\anaconda3\lib\site-packages (from geopandas) (2.2.2)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\ruizd\anaconda3\lib\site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=2.0.0 in c:\users\ruizd\anaconda3\lib\site-packages (from geopandas) (2.0.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ruizd\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ruizd\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ruizd\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2023.3)
# Requirement already satisfied: certifi in c:\users\ruizd\anaconda3\lib\site-packages (from pyogrio>=0.7.2->geopandas) (2024.8.30)
# Requirement already satisfied: six>=1.5 in c:\users\ruizd\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.16.0)

# %%
type(countries)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
# Se presenta el mapa de todos los países
countries.plot(facecolor="yellow",#este de acá es el relleno
               edgecolor='black', #este de acá las líneas
               linewidth=0.1) #grosor de las líneasb
# Out:
# <Axes: >

# %%
#Agregando las demás bases de datos...

rivers=gpd.read_file(os.path.join("World_Hydrography"))
cities=gpd.read_file(os.path.join("World_Cities"))

# %%
#Se grafican las ciudades:
cities.plot(marker='.',
            color='brown',
            markersize=1,
            alpha=0.3)
# Out:
# <Axes: >

# %%
#Se grafican los rios
rivers.plot(edgecolor='red',
            linewidth=1,
            linestyle='dotted')
# Out:
# <Axes: >

# %%
#Para verificar la proyección:
countries.crs==cities.crs==cities.crs
# Out:
# True

# %%
#Presentación en conjunto:
base = countries.plot(facecolor="white",
                      edgecolor='black',
                      linewidth=0.1,
                      figsize=(12,12))

rivers.plot(edgecolor='red', linewidth=0.4,
            ax=base)
cities.plot(marker='.', color='brown', markersize=1,alpha=0.7,
            ax=base)
# Out:
# <Axes: >

# %%
countries.to_file(os.path.join("worldMap.gpkg"),layer='countryBorders', driver="GPKG")
rivers.to_file(os.path.join("worldMap.gpkg"),layer='riverLines', driver="GPKG")
cities.to_file(os.path.join("worldMap.gpkg"),layer='cityPoints', driver="GPKG")

# %%
#Presentando el ejemplo de Venezuela:
venezuela=countries[countries.COUNTRY=='Venezuela']

# %%
citiesVenezuela_clipped = gpd.clip(gdf=cities,
                          mask=venezuela)
riversVenezuela_clipped = gpd.clip(gdf=rivers,
                               mask=venezuela)

# %%
#Ploteamos
base = venezuela.plot(facecolor="green", edgecolor='black', linewidth=0.4,figsize=(5,5))
citiesVenezuela_clipped.plot(marker='+', color='red', markersize=15,
                    ax=base)
riversVenezuela_clipped.plot(edgecolor='blue', linewidth=0.5,
                    ax=base)
# Out:
# <Axes: >

# %%
#chequeando los tipos:
venezuela.geom_type
# Out:
# 234    MultiPolygon
# dtype: object

# %%
citiesVenezuela_clipped.geom_type
# Out:
# 588    Point
# 242    Point
# 303    Point
# 241    Point
# 240    Point
# dtype: object

# %%
riversVenezuela_clipped.geom_type
# Out:
# 66         LineString
# 54    MultiLineString
# dtype: object

# %%
#Proyección del mapa
print(venezuela.crs)
# Out:
# EPSG:4326

# %%
venezuela.crs.axis_info
#ante la presencia de longitud y latitud, hay que reproyectar.
# Out:
# [Axis(name=Geodetic latitude, abbrev=Lat, direction=north, unit_auth_code=EPSG, unit_code=9122, unit_name=degree),
#  Axis(name=Geodetic longitude, abbrev=Lon, direction=east, unit_auth_code=EPSG, unit_code=9122, unit_name=degree)]

# %%
venezuela.to_crs(32619).crs.axis_info
# Out:
# [Axis(name=Easting, abbrev=E, direction=east, unit_auth_code=EPSG, unit_code=9001, unit_name=metre),
#  Axis(name=Northing, abbrev=N, direction=north, unit_auth_code=EPSG, unit_code=9001, unit_name=metre)]

# %%
venezuela.to_crs(32619).centroid
# Out:
# 234    POINT (815501.674 787859.729)
# dtype: geometry

# %%
#replot
base32619=venezuela.to_crs(32619).plot()
venezuela.to_crs(32619).centroid.plot(color='red',ax=base32619)
# Out:
# <Axes: >

# %%
venezuela_32619=venezuela.to_crs(32619)
cities_venezuela_32619=citiesVenezuela_clipped.to_crs(venezuela_32619.crs)
rivers_venezuela_32619=riversVenezuela_clipped.to_crs(venezuela_32619.crs)

# %%
import os

venezuela_32619.to_file(os.path.join("venezuelaMaps_32619.gpkg"), layer='country', driver="GPKG")
cities_venezuela_32619.to_file(os.path.join("venezuelaMaps_32619.gpkg"), layer='cities', driver="GPKG")
rivers_venezuela_32619.to_file(os.path.join("venezuelaMaps_32619.gpkg"), layer='rivers', driver="GPKG")

# %%
#comprobando el centroide:
venezuela_32619.centroid.to_file(os.path.join("venezuelaMaps_32619.gpkg"), layer='centroid', driver="GPKG")

# %%
import pandas as pd


infoairports=gpd.read_file(os.path.join("airports_points"))
infoairports.iloc[[0,1,2,3,-4,-3,-2,-1],:]
# Out:
#                     name          name_en    aeroway building emergency  \
# 0                   None             None    helipad     None      None
# 1                   None             None    helipad     None      None
# 2         Wasaraña Pista  Wasaraña Runway   airstrip     None      None
# 3    Base aerea El Vigia             None  aerodrome     None      None
# 670                 None             None    helipad     None      None
# 671                 None             None    helipad     None      None
# 672                 None             None    helipad     None      None
# 673                 None             None    helipad     None      None
#
#     emergency_ operator_t capacity_p  \
# 0         None       None       None
# 1         None       None       None
# 2         None       None       None
# 3         None       None       None
# 670       None       None       None
# 671       None       None       None
# 672       None       None       None
# 673       None       None       None
#
#                                              addr_full addr_city  \
# 0                                                 None      None
# 1                                                 None      None
# 2                                                 None      None
# 3    Aeropuerto Internacional Juan Pablo Pérez Alfonso  El Vigía
# 670                                               None      None
# 671                                               None      None
# 672                                               None      None
# 673                                               None      None
#
#               source              name_es       osm_id osm_type  \
# 0               None                 None  11371174510    nodes
# 1               None                 None  11371174511    nodes
# 2    ourairports.com                 None   1042092097    nodes
# 3               None  Base aerea El Vigia   4479775589    nodes
# 670             None                 None  11704668878    nodes
# 671             None                 None  11704668879    nodes
# 672             None                 None  11704668880    nodes
# 673             None                 None  11565738846    nodes
#
#                       geometry
# 0    POINT (-72.04947 7.05254)
# 1    POINT (-72.04906 7.05258)
# 2    POINT (-65.21412 4.73948)
# 3    POINT (-71.65966 8.62391)
# 670  POINT (-70.75115 7.06751)
# 671  POINT (-70.75127 7.06772)
# 672  POINT (-70.75085 7.06816)
# 673  POINT (-71.99034 7.02915)

# %%
airports_32619=infoairports.to_crs(32619)

base = venezuela_32619.plot(color='white', edgecolor='black')
airports_32619.plot(ax=base)
# Out:
# <Axes: >

# %%
# !pip install matplotlib
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(10, 10))
venezuela_32619.plot(ax=ax, color='white', edgecolor='black') 
venezuela_32619.plot(ax=ax, marker='o', color='blue', markersize=5) 
plt.title('Aeropuertos de Venezuela')
plt.show()
#CREAMOS EL MAPA DE LOS RIOS, CIUDADES Y AEROPUERTOS DE VENEZUELA.
base = venezuela_32619.plot(color='white', edgecolor='black')

airports_32619.plot(ax=base, color='green', markersize=5)

cities_venezuela_32619.plot(marker='+', color='red', markersize=30, ax=base)

rivers_venezuela_32619.plot(edgecolor='blue', linewidth=0.5, ax=base)
# Out:
# Requirement already satisfied: matplotlib in c:\users\ruizd\anaconda3\lib\site-packages (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ruizd\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ruizd\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ruizd\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ruizd\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.21 in c:\users\ruizd\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ruizd\anaconda3\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\ruizd\anaconda3\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ruizd\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ruizd\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\ruizd\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# <Axes: >
